# %%
import pandas as pd

# %%
#Question a
#Read the csv file named it dataset
dataset = pd.read_csv('~/Downloads/890/student_results.csv')

# %%
dataset
# Out:
#      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# 11    54055936         70.00         29.42           17.00          19.40
# ...

# %%
#Question b
# replace NA value with zeroes
dataset = dataset.fillna(0)
dataset
# Out:
#      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# 11    54055936         70.00         29.42           17.00          19.40
# ...

# %%
#Question c
#calculate the mark by dividing the total and multiply by the Weight
Assessment = dataset["Assessment 1"]/70*0.07 + dataset["Assessment 2"]/30*0.03 + dataset["Assessment 3"]/70*0.07 + dataset["Assessment 4"]/30*0.03
Online_Quiz = dataset["Online quiz 1 "]/30*0.03 + dataset["Online quiz 2"]/20*0.02 + dataset["Online quiz 3"]/30*0.03 + dataset["Online quiz 4"]/20*0.02
Group_Assignment = dataset["Group assignment 1"]/30*0.024 + dataset["Group assignment 2"]/20*0.016 + dataset["Group assignment 3"]/50*0.04
Group_evaluation = dataset[" Group evaluation"]/2*0.02
Final_exam = dataset["Final exam"]/100*0.6
#add up all the weight marks and multiply by 100, and create a new column call Total.marks
dataset["Total.marks"] = (Assessment + Online_Quiz + Group_Assignment + Group_evaluation + Final_exam)*100
dataset.head
# Out:
# <bound method NDFrame.head of      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#use the module seaborn to plot the boxplot
Q3bBoxplot = sns.boxplot(x="Student category", y = "Total.marks", data = dataset)

# %%
#Question d
#Calculate the mean, var and std of total marks for each class
mean = dataset[["Class No", "Total.marks"]].groupby('Class No').mean()
Variance = dataset[["Class No", "Total.marks"]].groupby('Class No').var()
Standard_deviation = dataset[["Class No", "Total.marks"]].groupby('Class No').std()
# Merge 3 table in to one stat_table by pandas
stat_table = pd.concat([mean, Variance, Standard_deviation], axis = 1)
#Change the colunms name of the table
stat_table.columns = ['Mean','Variance', 'Standard_deviation']
stat_table
# Out:
#                Mean    Variance  Standard_deviation
# Class No
# 1         59.280813  242.710561           15.579171
# 2         60.671069  160.151821           12.655110
# 3         57.610713  273.495919           16.537712
# 4         56.220069  319.034109           17.861526
# 5         57.918085  383.676678           19.587666
# 6         62.332600  252.025294           15.875305
# 7         54.879626  344.554792           18.562187
# 8         54.384800  358.580091           18.936211
# 9         53.918419  205.356479           14.330264
# 10        59.459821  286.748324           16.933645
# 11        53.123421  333.302820           18.256583
# 12        57.040716  239.145724           15.464337
# 15        57.521067  221.097589           14.869351
# 16        61.211431  179.019517           13.379818
# 17        56.857269  238.727958           15.450824
# 18        59.823636  242.163125           15.561591
# 19        56.263841   95.438828            9.769280
# ...

# %%
#Question e
#Give Grade to each student
Grade = list()

for marks in dataset['Total.marks']:
#Setting difference condition by if function
    if 0<= marks < 50:
        Grade.append('F')
    elif 50<= marks < 65:
        Grade.append('P')
    elif 65<= marks < 75:
        Grade.append('Cr')
    elif 75<= marks < 85:
        Grade.append('D')
    else:
        Grade.append('HD')
#create new colunm and equal to Grade,        
dataset['Grade'] = Grade
#print out the result
dataset
# Out:
#      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# 11    54055936         70.00         29.42           17.00          19.40
# ...

# %%
#Question f
import statsmodels.api as sm
#predictor
X = dataset["Assessment 1"]
#response
y = dataset["Final exam"]
#add a constant term in the regression
X = sm.add_constant(X)
#fit a simple regression model
model = sm.OLS(y, X).fit()
#make predictions by the model
predictions = model.predict(X)
#print out statistic result
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Final exam   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     61.55
# Date:                Thu, 17 May 2018   Prob (F-statistic):           2.11e-14
# Time:                        22:49:36   Log-Likelihood:                -2498.6
# No. Observations:                 578   AIC:                             5001.
# Df Residuals:                     576   BIC:                             5010.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#plot the regression garph
sns.lmplot("Assessment 1","Final exam", dataset)

# %%
#Question g
import statsmodels.api as sm
#Predictor
X = dataset[["Assessment 1", "Assessment 3", "Online quiz 1 ","Group assignment 2"]]
#response
y = dataset["Final exam"]
#adding constant term
X = sm.add_constant(X)
#perform multiple regression
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Final exam   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     29.05
# Date:                Thu, 17 May 2018   Prob (F-statistic):           5.21e-22
# Time:                        22:49:36   Log-Likelihood:                -2474.6
# No. Observations:                 578   AIC:                             4959.
# Df Residuals:                     573   BIC:                             4981.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
#Question h
#Give status to each students
X = list()

for Grade in dataset['Grade']:
    if Grade == 'F':
        X.append('Incomplete')
    else:
        X.append('Complete')
#create new column of Status       
dataset['Status'] = X
dataset
# Out:
#      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# 11    54055936         70.00         29.42           17.00          19.40
# ...

# %%
#changing status in to 1 or 0
X = list()

for Status in dataset['Status']:
    if Status == 'Complete':
        X.append('1')
    else:
        X.append('0')
        
dataset['Statusbinary'] = X
dataset
import sklearn.linear_model
from sklearn.linear_model import LogisticRegression
# Fit the logistic Regression for the first 100 students
y = dataset.loc[0:99,'Statusbinary']
x = dataset.loc[0:99,'Assessment 3']
x = sm.add_constant(x)
logreg = LogisticRegression()
logreg.fit(x, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
import sklearn.metrics
from sklearn.metrics import confusion_matrix
#construct the confusion matrix
y_true = dataset.loc[100:,'Statusbinary']
xtest = dataset.loc[100:,'Assessment 3']
xtest = sm.add_constant(xtest)
y_pred = logreg.predict(xtest)
confusion_matrix(y_true,y_pred)
# Out:
# array([[ 35,  90],
#        [ 14, 339]])
